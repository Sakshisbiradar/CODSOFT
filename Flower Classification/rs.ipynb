# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn import metrics

# %%
df = pd.read_csv('rs.csv', encoding= 'unicode_escape')

# %%
df.shape
# Out:
# (150, 5)

# %%
df.head()
# Out:
#     sepal_length  sepal_width  petal_length  petal_width      species
# 13           4.3          3.0           1.1          0.1  Iris-setosa
# 42           4.4          3.2           1.3          0.2  Iris-setosa
# 38           4.4          3.0           1.3          0.2  Iris-setosa
# 8            4.4          2.9           1.4          0.2  Iris-setosa
# 41           4.5          2.3           1.3          0.3  Iris-setosa

# %%
df.min()
# Out:
# sepal_length            4.3
# sepal_width             2.0
# petal_length            1.0
# petal_width             0.1
# species         Iris-setosa
# dtype: object

# %%
df.max()
# Out:
# sepal_length               7.9
# sepal_width                4.4
# petal_length               6.9
# petal_width                2.5
# species         Iris-virginica
# dtype: object

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df['species'].value_counts()
# Out:
# species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %%
y = np.array([50, 50, 50])
mylabels = ["Iris-setosa ", "Iris-setosa ", "Iris-virginica"]

plt.pie(y, labels = mylabels)
plt.legend()
plt.show()

# %%
# sorting data frame by sepal_length
df.sort_values("sepal_length", axis = 0, ascending = True,
                 inplace = True, na_position ='last')
 #display
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 13            4.3          3.0           1.1          0.1     Iris-setosa
# 42            4.4          3.2           1.3          0.2     Iris-setosa
# 38            4.4          3.0           1.3          0.2     Iris-setosa
# 8             4.4          2.9           1.4          0.2     Iris-setosa
# 41            4.5          2.3           1.3          0.3     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 122           7.7          2.8           6.7          2.0  Iris-virginica
# 118           7.7          2.6           6.9          2.3  Iris-virginica
# 117           7.7          3.8           6.7          2.2  Iris-virginica
# 135           7.7          3.0           6.1          2.3  Iris-virginica
# 131           7.9          3.8           6.4          2.0  Iris-virginica
#
# [150 rows x 5 columns]

# %%
# creating the bar plot for sepal length
sepallength = df['sepal_length']
species = df['species']


fig = plt.figure(figsize =(8, 5))

plt.bar(sepallength, species)

plt.show()

# %%
sns.barplot(x='sepal_width',y='species', hue='species', data=df)
plt.show()

# %%
#To know which species has the highest value of petal length and sepal length
sns.scatterplot(x='sepal_length', y='petal_length', data=df, hue='species' ,style="species")
plt.show()
#clearly virginica has the highest values for sepal

# %%
sns.scatterplot(x='sepal_length', y='petal_length', data=df, hue='petal_length')
plt.show()
#This shows petal length is directly propotional to the intensity of the dots it means higher petal length value higher is the sepal length.

# %%
sns.distplot(df['sepal_width'], color="purple")
plt.show()

# %%
sns.boxplot(x='species', y='petal_length',hue='species', data=df)
plt.title("Petal Length Of Different Species")
plt.xlabel("Species")
plt.ylabel("Petal Length")
plt.show()

# %%
#bar graph for petal length showing the maximum number of counts for each petal length value
#With the help of this graph we can see that petal length=1.5 has the highest value counts and petal length = 
#1,1.1,3,3.6,3.7,3.8,6.3,6.4,6.6,6.4,6.9 has the lowest value counts that is 1 

sns.set(rc={'figure.figsize':(20,5)})
ax = sns.countplot(data = df, x = 'petal_length')

for bars in ax.containers:
    ax.bar_label(bars)

# %%
#bar graph for sepal length showing the maximum number of counts for each sepal length value
#With the help of this graph we can see that sepal length=5 has the highest value counts and sepal length = 
#4.3,4.5,5.3,7,7.1,7.3,7.4,7.6,7.9 has the lowest value counts that is 1 
sns.set(rc={'figure.figsize':(20,5)})
ax = sns.countplot(data = df, x = 'sepal_length')

for bars in ax.containers:
    ax.bar_label(bars)

# %%
# !pip install scikit-learn

# %%
df.isnull().values.any()
# Out:
# False

# %%
df['species'].value_counts()
# Out:
# species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %%
sns.pairplot(df, hue='species', size=2).add_legend()
#From this below graph we are able to see that petal length and petal width are two most important measures to get proper accuracy.

# %%
for column in df.columns:
    if df[column].dtype == np.number:
        continue
        df[column]=LabelEncoder().fit_transform(df[column])

# %%
df.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
# !pip install linearRegression

# %%
train, test=train_test_split(df, test_size=0.25)

# %%
train
# Out:
#      sepal_length  sepal_width  petal_length  petal_width          species
# 67            5.8          2.7           4.1          1.0  Iris-versicolor
# 31            5.4          3.4           1.5          0.4      Iris-setosa
# 136           6.3          3.4           5.6          2.4   Iris-virginica
# 104           6.5          3.0           5.8          2.2   Iris-virginica
# 144           6.7          3.3           5.7          2.5   Iris-virginica
# ..            ...          ...           ...          ...              ...
# 10            5.4          3.7           1.5          0.2      Iris-setosa
# 15            5.7          4.4           1.5          0.4      Iris-setosa
# 53            5.5          2.3           4.0          1.3  Iris-versicolor
# 32            5.2          4.1           1.5          0.1      Iris-setosa
# 37            4.9          3.1           1.5          0.1      Iris-setosa
#
# [112 rows x 5 columns]

# %%
test
# Out:
#      sepal_length  sepal_width  petal_length  petal_width          species
# 120           6.9          3.2           5.7          2.3   Iris-virginica
# 115           6.4          3.2           5.3          2.3   Iris-virginica
# 19            5.1          3.8           1.5          0.3      Iris-setosa
# 13            4.3          3.0           1.1          0.1      Iris-setosa
# 30            4.8          3.1           1.6          0.2      Iris-setosa
# 72            6.3          2.5           4.9          1.5  Iris-versicolor
# 119           6.0          2.2           5.0          1.5   Iris-virginica
# 2             4.7          3.2           1.3          0.2      Iris-setosa
# 42            4.4          3.2           1.3          0.2      Iris-setosa
# 58            6.6          2.9           4.6          1.3  Iris-versicolor
# 118           7.7          2.6           6.9          2.3   Iris-virginica
# ...

# %%
train_X=train[['sepal_length', 'sepal_width', 'petal_length', 'petal_width']]

# %%
train_Y=train.species

# %%
train_X
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 67            5.8          2.7           4.1          1.0
# 31            5.4          3.4           1.5          0.4
# 136           6.3          3.4           5.6          2.4
# 104           6.5          3.0           5.8          2.2
# 144           6.7          3.3           5.7          2.5
# ..            ...          ...           ...          ...
# 10            5.4          3.7           1.5          0.2
# 15            5.7          4.4           1.5          0.4
# 53            5.5          2.3           4.0          1.3
# 32            5.2          4.1           1.5          0.1
# 37            4.9          3.1           1.5          0.1
#
# [112 rows x 4 columns]

# %%
train_Y
# Out:
# 67     Iris-versicolor
# 31         Iris-setosa
# 136     Iris-virginica
# 104     Iris-virginica
# 144     Iris-virginica
#             ...
# 10         Iris-setosa
# 15         Iris-setosa
# 53     Iris-versicolor
# 32         Iris-setosa
# 37         Iris-setosa
# Name: species, Length: 112, dtype: object

# %%
test_X=test[['sepal_length', 'sepal_width', 'petal_length', 'petal_width']]

# %%
test_Y=test.species

# %%
model=svm.SVC()

# %%
model.fit(train_X,train_Y)
pred= model.predict(test_X)

# %%
metrics.accuracy_score(pred,test_Y)
# Out:
# 0.9736842105263158

# %%
pred=model.predict(test_X)

# %%
metrics.accuracy_score(pred,test_Y)
# Out:
# 0.9473684210526315

# %%
from sklearn.metrics import classification_report
print (classification_report(test_Y, pred))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        16
# Iris-versicolor       0.85      1.00      0.92        11
#  Iris-virginica       1.00      0.82      0.90        11
#
#        accuracy                           0.95        38
#       macro avg       0.95      0.94      0.94        38
#    weighted avg       0.96      0.95      0.95        38

# %%
df['species'], categories=pd.factorize(df['species'])
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width  species
# 0           5.1          3.5           1.4          0.2        0
# 1           4.9          3.0           1.4          0.2        0
# 2           4.7          3.2           1.3          0.2        0
# 3           4.6          3.1           1.5          0.2        0
# 4           5.0          3.6           1.4          0.2        0

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      sepal_length  sepal_width  petal_length  petal_width  species
# 0             5.1          3.5           1.4          0.2        0
# 1             4.9          3.0           1.4          0.2        0
# 2             4.7          3.2           1.3          0.2        0
# 3             4.6          3.1           1.5          0.2        0
# 4             5.0          3.6           1.4          0.2        0
# ..            ...          ...           ...          ...      ...
# 145           6.7          3.0           5.2          2.3        2
# 146           6.3          2.5           5.0          1.9        2
# 147           6.5          3.0           5.2          2.0        2
# 148           6.2          3.4           5.4          2.3        2
# 149           5.9          3.0           5.1          1.8        2
#
# [150 rows x 5 columns]>

# %%
sns.scatterplot(x='petal_length', y='petal_width', data=df, hue='petal_length')
plt.show()
#This scatterplot makes the dataset quite predictable and classify the species efficiently.

# %%
#SAKSHI BIRADAR
#TASK 3
#IRIS FLOWER CLASSIFICATION
